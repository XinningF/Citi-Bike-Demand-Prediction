# %%
import numpy as np
import pandas as pd
import seaborn as sn
from datetime import datetime
# import matplotlib.pyplot as plt
# import warnings
# from sklearn.model_selection import GridSearchCV
from sklearn import metrics
# import xgboost as xgb
# pd.options.mode.chained_assignment = None
# warnings.filterwarnings("ignore", category=DeprecationWarning)
# %matplotlib inline

# %%
# Load weather data
weather_data = pd.read_csv('./Data/Weather/cleaned_weather.csv')
citi_data = pd.read_csv('./Data/Citi_Bike/reduced_data.csv')

citi_data.head()
# Out:
#    Unnamed: 0           ride_id rideable_type           started_at  \
# 0           0  E12103A91226099A   docked_bike  2021-05-06 17:25:01
# 1           1  26A3DC47FE0EA3A3   docked_bike  2021-05-13 12:48:08
# 2           2  A99F2E1D627B088F   docked_bike  2021-05-16 08:30:13
# 3           3  43E79A45997B7390   docked_bike  2021-05-01 08:38:14
# 4           4  8B3CC649F4F58816   docked_bike  2021-05-09 08:12:31
#
#               ended_at  start_station_name        end_station_name  \
# 0  2021-05-06 17:45:25  Broadway & W 60 St         1 Ave & E 78 St
# 1  2021-05-13 13:07:37  Broadway & W 25 St       E 2 St & Avenue B
# 2  2021-05-16 08:45:47       46 Ave & 5 St  34th Ave & Vernon Blvd
# 3  2021-05-01 08:54:27       46 Ave & 5 St  34th Ave & Vernon Blvd
# 4  2021-05-09 08:27:05       46 Ave & 5 St  34th Ave & Vernon Blvd
#
#   member_casual
# 0        member
# 1        member
# 2        member
# 3        member
# 4        member

# %%
citi_data = citi_data.drop(citi_data.columns[0], axis = 1)
citi_data.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  E12103A91226099A   docked_bike  2021-05-06 17:25:01  2021-05-06 17:45:25
# 1  26A3DC47FE0EA3A3   docked_bike  2021-05-13 12:48:08  2021-05-13 13:07:37
# 2  A99F2E1D627B088F   docked_bike  2021-05-16 08:30:13  2021-05-16 08:45:47
# 3  43E79A45997B7390   docked_bike  2021-05-01 08:38:14  2021-05-01 08:54:27
# 4  8B3CC649F4F58816   docked_bike  2021-05-09 08:12:31  2021-05-09 08:27:05
#
#    start_station_name        end_station_name member_casual
# 0  Broadway & W 60 St         1 Ave & E 78 St        member
# 1  Broadway & W 25 St       E 2 St & Avenue B        member
# 2       46 Ave & 5 St  34th Ave & Vernon Blvd        member
# 3       46 Ave & 5 St  34th Ave & Vernon Blvd        member
# 4       46 Ave & 5 St  34th Ave & Vernon Blvd        member

# %%
# test = weather_data.loc[pd.to_datetime(weather_data["Date"]).dt.date == pd.to_datetime(citi_data["started_at"][0]).date()]
df = citi_data.copy()
for index, row in citi_data.iterrows():
    date_data = row["started_at"]
    weather_data_matched = weather_data.loc[pd.to_datetime(weather_data["Date"]).dt.date == pd.to_datetime(date_data).date()]
    weather_data_matched = weather_data_matched.drop(["Date"], axis = 1)

    df[index]
# Out:
#           Date    AWND      PRCP  SNOW  SNWD       TAVG       TMAX       TMIN
# 35  2021-05-06  9.7875  0.292644   0.0   0.0  58.333333  63.538462  48.384615
#       AWND      PRCP  SNOW  SNWD       TAVG       TMAX       TMIN
# 35  9.7875  0.292644   0.0   0.0  58.333333  63.538462  48.384615
#           Date     AWND  PRCP  SNOW  SNWD       TAVG       TMAX       TMIN
# 42  2021-05-13  6.23625   0.0   0.0   0.0  61.333333  69.076923  45.769231
#        AWND  PRCP  SNOW  SNWD       TAVG       TMAX       TMIN
# 42  6.23625   0.0   0.0   0.0  61.333333  69.076923  45.769231
#           Date    AWND      PRCP  SNOW  SNWD  TAVG       TMAX       TMIN
# 45  2021-05-16  5.3125  0.000235   0.0   0.0  66.0  75.769231  53.307692
#       AWND      PRCP  SNOW  SNWD  TAVG       TMAX       TMIN
# 45  5.3125  0.000235   0.0   0.0  66.0  75.769231  53.307692
#           Date      AWND      PRCP  SNOW  SNWD       TAVG       TMAX  \
# ...

# %% [markdown]
# AWND - Average daily wind speed (meters per second or miles per hour as per user preference)
#
# DAPR - Number of days included in the multiday precipitation total (MDPR)
#
# DASF - Number of days included in the multiday snowfall total (MDSF)
#
# MDPR - Multiday precipitation total (mm or inches as per user preference; use with DAPR and DWPR, if available)
#
# MDSF - Multiday snowfall total (mm or inches as per user preference)
#
# SNWD -  Snow depth (mm or inches as per user preference, inches on Daily Form pdf file)
